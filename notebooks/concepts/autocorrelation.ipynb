# %%
import pandas as pd
import xarray as xr
from src.data import load_interim
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf

filename = "era5_precipitation_timeseries_alegrete_1D.nc"
path = load_interim(filename)

nc_dataset = xr.open_dataset(path, engine="netcdf4")
tp = nc_dataset["tp"]
df = tp.to_dataframe(name="total_precipitation")
series = pd.Series(df["total_precipitation"])

series.autocorr()
# Out:
# np.float64(0.20774368493130096)
